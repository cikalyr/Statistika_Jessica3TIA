# %%
import pandas as pd

# %%
path = "JessicaLyra_3TIA_LatihanOnline.xlsx"
dataraw = pd.read_excel(path)
print(dataraw)
# Out:
#     Unnamed: 0            ID                Name  \
# 0          NaN  JESSICA LYRA                 NaN
# 1          NaN    2455301085                 NaN
# 2          NaN           NaN                 NaN
# 3          NaN        120001            John Doe
# 4          NaN        120005          Jane Smith
# 5          NaN        120017     Michael Johnson
# 6          NaN        120018         Emily Brown
# 7          NaN        120022     Daniel Martinez
# 8          NaN        120024        Sarah Wilson
# 9          NaN        120025        David Garcia
# 10         NaN        120027         Jessica Lee
# 11         NaN        120034       Matthew Davis
# 12         NaN        120035  Jennifer Rodriguez
# 13         NaN        120036       Andrew Taylor
# 14         NaN        120038    Amanda Hernandez
# 15         NaN        120039   Christopher Clark
# 16         NaN        120046  Elizabeth Martinez
# 17         NaN        120047    William Anderson
# 18         NaN        120049       Sophia Thomas
# 19         NaN        120054         James White
# 20         NaN        120060       Olivia Taylor
# 21         NaN        120063     Benjamin Wilson
# 22         NaN        120070         Emma Garcia
# 23         NaN        120071     Alexander Davis
# 24         NaN        120073           Mia Moore
# 25         NaN        120082       Ethan Jackson
# 26         NaN        120083      Isabella Brown
# 27         NaN        120088         Noah Taylor
# 28         NaN        120090     Abigail Johnson
# 29         NaN        120093      Logan Martinez
# 30         NaN        120095         Avery Clark
# 31         NaN        120098      Jacob Thompson
# 32         NaN        120099     Samantha Harris
#
#     Marks in Quiz\n (Out of 100)  Mid Term Results (Out of 100)  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                           90.0                           75.0
# 3                           85.0                           78.0
# 4                           92.0                           88.0
# 5                           48.0                           65.0
# 6                           90.0                           85.0
# 7                           75.0                           80.0
# 8                           88.0                           70.0
# 9                           75.0                           70.0
# 10                          95.0                           91.0
# 11                          79.0                           84.0
# 12                          42.0                           48.0
# 13                          53.0                           64.0
# 14                          91.0                           95.0
# 15                          76.0                           81.0
# 16                          89.0                           93.0
# 17                          80.0                           85.0
# 18                          94.0                           90.0
# 19                          77.0                           82.0
# 20                          86.0                           89.0
# 21                          92.0                           88.0
# 22                          78.0                           83.0
# 23                          41.0                           53.0
# 24                          68.0                           49.0
# 25                          81.0                           87.0
# 26                          87.0                           90.0
# 27                          79.0                           84.0
# 28                          70.0                           77.0
# 29                          67.0                           54.0
# 30                          69.0                           62.0
# 31                          76.0                           81.0
# 32                          60.0                           65.0
#
#     Final Term Resul  (Out of 100)  Final Score Grade
# 0                              NaN          NaN   NaN
# 1                              NaN          NaN   NaN
# 2                             85.0        83.30     A
# 3                             90.0        84.44     A
# 4                             94.0        91.38     A
# 5                             56.0        56.41     C
# 6                             88.0        87.65     A
# 7                             77.0        77.35    AB
# 8                             65.0        74.01     B
# 9                             75.0        73.35     B
# 10                            96.0        94.03     A
# 11                            78.0        80.30     A
# 12                            63.0        51.33     C
# 13                            59.0        58.73     C
# 14                            90.0        91.97     A
# 15                            75.0        77.30    AB
# 16                            88.0        89.97     A
# 17                            79.0        81.30     A
# 18                            95.0        93.03     A
# 19                            76.0        78.30    AB
# 20                            84.0        86.29     A
# 21                            93.0        91.03     A
# 22                            77.0        79.30    AB
# 23                            44.0        46.01     F
# 24                            54.0        56.83     C
# 25                            80.0        82.63     A
# 26                            85.0        87.29     A
# 27                            78.0        80.30     A
# 28                            64.0        70.21     B
# 29                            54.0        58.16     C
# 30                            71.0        67.39     B
# 31                            75.0        77.30    AB
# 32                            64.0        63.05    BC

# %%
datafrq = pd.crosstab(index=dataraw["Grade"], columns="Frekuensi")
print(datafrq)
# Out:
# col_0  Frekuensi
# Grade
# A             15
# AB             5
# B              4
# BC             1
# C              5
# F              1

# %%
datafrq.plot()
# Out:
# <Axes: xlabel='Grade'>

# %%
datafrq.plot(kind='bar')
# Out:
# <Axes: xlabel='Grade'>

# %%
datafrq.plot(kind='pie', y='Frekuensi', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Frekuensi'>

# %%
# Statistika Deskriptif
dataraw["Final Score"] = pd.to_numeric(dataraw["Final Score"], errors='coerce')
dt = dataraw["Final Score"]

stats = dt.describe()
stats['Standard Error'] = dt.sem()
stats['Median'] = dt.median()
stats['Mode'] = dt.mode().iloc[0]
stats['variance'] = dt.var()
stats['range'] = dt.max() - dt.min()
stats['skewness'] = dt.skew()
stats['kurtosis'] = dt.kurtosis()

print(stats)
# Out:
# count              31.000000
# mean               76.449677
# std                13.301140
# min                46.010000
# 25%                68.800000
# 50%                79.300000
# 75%                86.790000
# max                94.030000
# Standard Error      2.388955
# Median             79.300000
# Mode               77.300000
# variance          176.920330
# range              48.020000
# skewness           -0.714465
# kurtosis           -0.433769
# Name: Final Score, dtype: float64
